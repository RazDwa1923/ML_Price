# %%
# Importing Libraries
import pandas as pd

# Importing Data
path = '/Users/karolk/Python_Work/Data_Sets/Global_Data/CoinGecko_API_Data.csv'
df = pd.read_csv(path)

# Displaying Data
df
# Out:
#                  id symbol            name  \
# 0           bitcoin    btc         Bitcoin
# 1          ethereum    eth        Ethereum
# 2            tether   usdt          Tether
# 3       binancecoin    bnb             BNB
# 4            solana    sol          Solana
# ..              ...    ...             ...
# 747             uma    uma             UMA
# 748  convex-finance    cvx  Convex Finance
# 749            myro  $myro            Myro
# 750       neutron-3   ntrn         Neutron
# 751  xai-blockchain    xai             Xai
#
#                                                  image current_price  \
# 0    https://assets.coingecko.com/coins/images/1/la...    70307.9075
# 1    https://assets.coingecko.com/coins/images/279/...     3606.3935
# 2    https://assets.coingecko.com/coins/images/325/...        1.0001
# 3    https://assets.coingecko.com/coins/images/825/...      605.2301
# 4    https://assets.coingecko.com/coins/images/4128...      196.8637
# ...
